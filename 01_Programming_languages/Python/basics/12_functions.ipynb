# %% [markdown]
# # Functions

# %%
# len , print are built in functions
# below functions are user defined functions
# indentation in py reprsents code block

# %%
# declaring functions -> def keyword
def my_function():
    print("hello")

# calling functions
my_function()
# Out:
# hello

# %%
# functions - Reeborg's world
# https://reeborg.ca/reeborg.html?lang=en&mode=python&menu=worlds%2Fmenus%2Freeborg_intro_en.json&name=Alone&url=worlds%2Ftutorial_en%2Falone.json

def turn_around():
    turn_left()
    turn_left()
    
def turn_right():
    turn_left()
    turn_left()
    turn_left()
    
def draw_square():
    turn_left()
    move()
    turn_right()
    move()
    turn_right()
    move()
    turn_right()
    move()

# %%
def hello_function ():
    pass

print(hello_function)  #<function hello_function at 0x0000024EE26B2EE0>
print(hello_function()) #None
# Out:
# <function hello_function at 0x0000024EE26B2EE0>
# None

# %%
def hello_function ():
    print("hello")
    return "hello"

print(hello_function())
# Out:
# hello
# hello

# %%
print(hello_function().upper())
# Out:
# hello
# HELLO

# %% [markdown]
# # Function with inputs

# %%
# name -> parameter(name of the data that's being passed in)
def greet(name):
    print(f"Hello {name}")
    
# amruta - argument(actual value of the data)
greet("amruta")
# Out:
# Hello amruta

# %%
# function with more parameters
def greet_with(name,location):
    print(f"hello {name}")
    print(f"how is it like in your {location}")
    
# positional arguments    
greet_with("x","y")

# keyword arguments
greet_with( location="x", name="y")
# Out:
# hello x
# how is it like in your y
# hello y
# how is it like in your x

# %%
def hello_function(greeting):
     return'{} Function.'.format(greeting)

print(hello_function('hi'))
# Out:
# hi Function.

# %%
def hello_function(greeting, name='you'):
     return'{}, {}' .format(greeting, name)

print(hello_function('hi'))
# Out:
# hi, you

# %%
print(hello_function('hi' ,name='corey'))
# Out:
# hi, corey

# %%
def student_info(*args,  **kwargs):
    print(args)
    print(kwargs)

student_info('math', 'art', name='john', age=22)
# Out:
# ('math', 'art')
# {'name': 'john', 'age': 22}

# %%
courses =  ['math', 'art']   
info = {'name':'john', 'age':22 } 

student_info(*courses, **info)
# Out:
# ('math', 'art')
# {'name': 'john', 'age': 22}

# %%
#number of days per month.
#first value of placeholder for indexing purposes.

month_days = [0, 31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31]

def is_leap(year):
    """return True for leap years, False for non leap years."""
    return year % 4 == 0 and (year % 100 != 0 or year % 400 == 0)

    
def days_in_months(year, month):
    """return number of days in that month in that year"""  
    if not 1 <= month <= 12:
        return 'invalid month'  
    if month == 2 and is_leap(year):
        return 29

print(is_leap(2016))      
print(days_in_months(2024, 2))
# Out:
# True
# 29

# %% [markdown]
# # Function with outputs

# %%
# Function with outputs that return a single value
def my_function():
    result = 3*2
    return result
output = my_function()
print(output)
# Out:
# 6

# %%
def format_name(f_name, l_name):
    return f"{f_name.title()} {l_name.title()} "
    
print(format_name("anGela", "yu") )
# Out:
# Angela Yu

# %%
# Multiple return values
def format_name(f_name, l_name):
    # Docstrings - gives documentation of function while using it 
    '''Returns title case of name'''
    if ( f_name == "" or l_name == "" ):
        return "please provide valid inputs"
    return f"{f_name.title()} {l_name.title()} "

print(format_name(input("What is your first name? "), input("What is your last name? ")) )
# Out:
# What is your first name? Angela
# What is your last name? yu
# Angela Yu

# %%
# recursion is a function which call itself's

# %% [markdown]
# # arguments with default values

# %%
# arguments with default values
def my_func(a=1, b=2, c=3):
    print(f"{a} {b} {c}")

my_func()
my_func(c=10)
# Out:
# 1 2 3
# 1 2 10

# %%
# example turtle write method have move,align,font arguments optional hence they already have a default value and
# only one required positional argument arg
# align - center (default)
# move - False (default)
