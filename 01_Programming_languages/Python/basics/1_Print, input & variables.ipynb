# %% [markdown]
#  # print function

# %%
# print tells what to print
# "" , '' --> represent string
print("Hello, world!")
# Out:
# Hello, world!

# %%
print(print(3))
# Out:
# 3
# None

# %%
#3 single quotes for multiline     
print('''
      This 
      is a
      multilined text
                                 
      ''')
# Out:
#       This
#       is a
#       multilined text

# %%
a = 10
b = 20
c = a+b
print("Addition of number {0} and {1} is {2}".format(a,b,c))
# Out:
# Addition of number 10 and 20 is 30

# %%
print("a","b","c","d", sep = "+",end='\t')
print("a","b","c","d", sep = "+")
print("a","b","c","d", sep = " blaan ")
# Out:
# a+b+c+d	a+b+c+d
# a blaan b blaan c blaan d

# %% [markdown]
# # Input function

# %%
#input("A prompt from the user")
print("Hello " + input("what is your name "))
# Out:
# what is your name nama
# Hello nama

# %% [markdown]
# # variables

# %%
user_name = input("Name: ")
print(user_name)
# Out:
# Name: bob
# bob
# jack

# %%
name = "jack"
print(name)
# Out:
# jack
