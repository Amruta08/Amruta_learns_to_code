# %% [markdown]
# <h3>Table of contents</h3>
#
# <strong>Day 1</strong>
# <ol>
#     <li>print function</li>
#     <li>Debugging</li>
#     <li>input function</li>
#     <li>Variables play</li>
# </ol>
#
# <strong>Day 2</strong>
# <ol>
#     <li>Data types</li>
#     <li>BMI Calculator</li>
#     <li>life in weeks</li>
# </ol>
#
# <strong>Day 3</strong>
# <ol>
#     <li>Odd or even</li>
#     <li>Updated bmi Calculator</li>
#     <li>Leap year</li>
#     <li>Pizza order</li>
#     <li>love calculator</li>
# </ol>
#
# <strong>Day 4</strong>
# <ol>
#     <li>Heads or tails</li>
#     <li>Who will pay for lunch</li>
#     <li>Leap year</li>
# </ol>
#
# <strong>Day 5</strong>
# <ol>
#     <li>Average height</li>
#     <li>High score</li>
#     <li>Adding even numbers</li>
#     <li>FizzBuzz</li>
# </ol>
#
# <strong>Day 6</strong>
# <ol>
#     <li>Hurdles loop</li>
# </ol>
#
# <strong>Day 8</strong>
# <ol>
#     <li>Area Calc</li>
# </ol>

# %% [markdown]
# # Ex 1.1 (print function)

# %%
print("Day 1 - Python Print Function")
print("The function is declared like this:")
print("print('what to print')")
# Out:
# Day 1 - Python Print Function
# The function is declared like this:
# print('what to print')

# %% [markdown]
# # Ex 1.2 (debugging)

# %%
#broken code
# print(Day 1 - String Manipulation")
# print("String Concatenation is done with the "+" sign.")
#   print('e.g. print("Hello " + "world")')
# print(("New lines can be created with a backslash and n.")

#fixed code
print("Day 1 - String Manipulation")
print('String Concatenation is done with the "+" sign.')
print('e.g. print("Hello " + "world")')
print("New lines can be created with a backslash and n.")
# Out:
# Day 1 - String Manipulation
# String Concatenation is done with the "+" sign.
# e.g. print("Hello " + "world")
# New lines can be created with a backslash and n.

# %% [markdown]
# # Ex 1.3 (input function)

# %%
print(len(input()))
# Out:
# amruta
# 6

# %% [markdown]
# # Ex 1.4  (variables play)

# %%
# 🚨 Don't change the code below 👇
a = input("a: ")
b = input("b: ")
# 🚨 Don't change the code above 👆

####################################
#Write your code below this line 👇
temp = a 
a = b
b = temp 

#Write your code above this line 👆
####################################

# 🚨 Don't change the code below 👇
print("a: " + a)
print("b: " + b)
# Out:
# a: 10
# b: 20
# a: 20
# b: 10

# %% [markdown]
# # Ex 2.1 (Data types)

# %%
# 🚨 Don't change the code below 👇
two_digit_number = input("Type a two digit number: ")
# 🚨 Don't change the code above 👆

####################################
#Write your code below this line 👇
a = int(two_digit_number[0])
b = int(two_digit_number[1])

print(a+b)
# Out:
# Type a two digit number: 57
# 12

# %% [markdown]
# # Ex 2.2 (BMI Calculator)

# %%
# 🚨 Don't change the code below 👇
height = input("enter your height in m: ")
weight = input("enter your weight in kg: ")
# 🚨 Don't change the code above 👆

#Write your code below this line 👇
print(int((float(weight)/(float(height)**2))))
# Out:
# enter your height in m: 1.75
# enter your weight in kg: 80
# 26

# %% [markdown]
# # Ex 2.3 (Your life in weeks)

# %%
# 🚨 Don't change the code below 👇
age = input("What is your current age?")
# 🚨 Don't change the code above 👆

#Write your code below this line 👇
Age = int(age)
months = (90-Age)*12
weeks = (90-Age)*52
days = (90-Age)*365

print(f"You have {days} days, {weeks} weeks and {months} months left")
# Out:
# What is your current age? 19
# You have 25915 days, 3692 weeks and 852 months left

# %% [markdown]
# # Ex 3.1(Odd or even?)

# %%
# 🚨 Don't change the code below 👇
number = int(input("Which number do you want to check? "))
# 🚨 Don't change the code above 👆

#Write your code below this line 👇
if(number%2==0):
    print("This is an even number.")
else:
    print("This is an odd number.")
# Out:
# Which number do you want to check? 35
# This is an odd number.

# %% [markdown]
# # Ex 3.2(BMI calculator updated)

# %%
# 🚨 Don't change the code below 👇
height = float(input("enter your height in m: "))
weight = float(input("enter your weight in kg: "))
# 🚨 Don't change the code above 👆

#Write your code below this line 👇
BMI = round(weight/height**2)

if(BMI<18.5):
    print(f" Your BMI is {BMI} ,You are underweight")
elif(BMI<25):
    print(f" Your BMI is {BMI} ,You have a normal weight")
elif(BMI<30):
    print(f" Your BMI is {BMI} ,You are slightly overweight")
elif(BMI<35):
    print(f" Your BMI is {BMI} ,You are obese")
else:
    print(f" Your BMI is {BMI} ,You are clinically obese.")
# Out:
# enter your height in m: 1.72
# enter your weight in kg: 50
#  Your BMI is 17 ,You are underweight

# %% [markdown]
# # Ex 3.3(Leap year)

# %%
# 🚨 Don't change the code below 👇
year = int(input("Which year do you want to check? "))
# 🚨 Don't change the code above 👆

#Write your code below this line 👇
if(year%4==0):
    if(year%100==0):
        if(year%400==0):
            print("Leap year")
        else:    
            print("Not a Leap year")    
    else:
        print("Leap year")
else:
    print("Not a Leap year")
# Out:
# Which year do you want to check? 2020
# Leap year

# %% [markdown]
# # Ex 3.4(Pizza order practice)

# %%
# 🚨 Don't change the code below 👇
print("Welcome to Python Pizza Deliveries!")
size = input("What size pizza do you want? S, M, or L ")
add_pepperoni = input("Do you want pepperoni? Y or N ")
extra_cheese = input("Do you want extra cheese? Y or N ")
# 🚨 Don't change the code above 👆

#Write your code below this line 👇
price = 0

if(size == "S"):
    price = 15     
elif(size == "M"):
    price = 20
elif(size == "L"):
    price = 25
else:
    print("Enter valid choice")
    
if(add_pepperoni == "Y"):
    if(size =="s"):
        price+=2
    else:
        price+=3
    
if(extra_cheese == "Y"):
    price+=1
    
print(f"Your final bill is ${price}")
# Out:
# Welcome to Python Pizza Deliveries!
# What size pizza do you want? S, M, or L L
# Do you want pepperoni? Y or N Y
# Do you want extra cheese? Y or N Y
# Your final bill is $29

# %% [markdown]
# # Ex 3.5(Love Calculator)

# %%
# 🚨 Don't change the code below 👇
print("Welcome to the Love Calculator!")
name1 = input("What is your name? \n")
name2 = input("What is their name? \n")
# 🚨 Don't change the code above 👆

#Write your code below this line 👇

# converting string to lower case
Lower1 = name1.lower()
Lower2 = name2.lower()

# counting l,o,v,e,t,r,u from both words and storing count of each in diff. variable
L = Lower1.count("l") + Lower2.count("l")
O = Lower1.count("o") + Lower2.count("o")
V = Lower1.count("v") + Lower2.count("v")
E = Lower1.count("e") + Lower2.count("e")
T = Lower1.count("t") + Lower2.count("t")
R = Lower1.count("r") + Lower2.count("r")
U = Lower1.count("u") + Lower2.count("u")

# converting count of total characters in true and love in string
initial = str(T + R + U + E)
final = str(L + O + V + E)

# concatenating count of true and false
score = int(initial + final)

if(score<10 or score>90):
    print(f"Your score is {score}% ,you go together like coke and mentos.")
elif(score<50 and score>40):
    print(f"Your score is {score}% ,you are alright together.")
else:
    print(f"Your score is {score}%.")
# Out:
# Welcome to the Love Calculator!
# What is your name?
# Angela yu
# What is their name?
# jack bauer
# Your score is 53% ,you are alright together.

# %%
# 🚨 Don't change the code below 👇
print("Welcome to the Love Calculator!")
name1 = input("What is your name? \n")
name2 = input("What is their name? \n")
# 🚨 Don't change the code above 👆

combined = name1+name2
low = combined.lower()

l = low.count('l')
o = low.count('o')
v = low.count('v')
e = low.count('e')
t = low.count('t')
r = low.count('r')
u = low.count('u')

love = l + o + v + e
true = t + r + u + e

score = int(str(true) + str(love))

if(score<10 or score>90):
    print(f"Your score is {score}% ,you go together like coke and mentos.")
elif(score<50 and score>40):
    print(f"Your score is {score}% ,you are alright together.")
else:
    print(f"Your score is {score}%.")
# Out:
# Welcome to the Love Calculator!
# What is your name?
# LOVE
# What is their name?
# TRUE
# Your score is 55%.

# %% [markdown]
# # Ex 4.1  (Head or tails ?)

# %%
#Write your code below this line 👇
import random
rad = random.randint(0,1)
if(rad == 1):
    print("Heads")
else:
    print("Tails")
    
#Hint: Remember to import the random module first. 🎲
# Out:
# Heads

# %% [markdown]
# # Ex 4.2 (Who will pay for lunch?)

# %%
# Split string method
names_string = input("Give me everybody's names, separated by a comma. ")
names = names_string.split(", ")
# 🚨 Don't change the code above 👆
import random

length = len(names)
randomint = random.randint(0,length)
print(f"{names[randomint]}, will pay for the lunch") 

#Write your code below this line 👇
# Out:
# Give me everybody's names, separated by a comma. a, b, c
# b, will pay for the lunch

# %% [markdown]
# # Ex 4.3 (Treasure Map)

# %%
# 🚨 Don't change the code below 👇
row1 = ["⬜️","⬜️","⬜️"]
row2 = ["⬜️","⬜️","⬜️"]
row3 = ["⬜️","⬜️","⬜️"]
map = [row1, row2, row3]
print(f"{row1}\n{row2}\n{row3}")
position = input("Where do you want to put the treasure? ")
# 🚨 Don't change the code above 👆

#Write your code below this row 👇
col = int((position[0]))
row = int((position[1]))

map[row-1][col-1] = 'x'

#Write your code above this row 👆

# 🚨 Don't change the code below 👇
print(f"{row1}\n{row2}\n{row3}")
# Out:
# ['⬜️', '⬜️', '⬜️']
# ['⬜️', '⬜️', '⬜️']
# ['⬜️', '⬜️', '⬜️']
# Where do you want to put the treasure? 31
# ['⬜️', '⬜️', 'x']
# ['⬜️', '⬜️', '⬜️']
# ['⬜️', '⬜️', '⬜️']

# %% [markdown]
# # Ex 5.1 (Average height)

# %%
# 🚨 Don't change the code below 👇
student_heights = input("Input a list of student heights ").split()
for n in range(0, len(student_heights)):
  student_heights[n] = int(student_heights[n])
# 🚨 Don't change the code above 👆

#Write your code below this row 👇

#calculating sum of numbers and no. of elements in list
count = 0
total = 0
for student in student_heights:
    total += student
    count += 1

# displaying average
print(round(total/count))
# Out:
# Input a list of student heights 156 178 165 171 187
# 171

# %% [markdown]
# # Ex 5.2 (High score)

# %%
# 🚨 Don't change the code below 👇
student_scores = input("Input a list of student scores ").split()
for n in range(0, len(student_scores)):
  student_scores[n] = int(student_scores[n])
print(student_scores)
# 🚨 Don't change the code above 👆

#Write your code below this row 👇

# finding max element using if 
score_initial = 0
for score in student_scores:
    if(score_initial < score):
        score_initial = score
        
print(f"The highest score is {score_initial}")
# Out:
# Input a list of student scores 78 65 89 86 55 91 64 89
# [78, 65, 89, 86, 55, 91, 64, 89]
# The highest score is 91

# %% [markdown]
# # Ex 5.3(Adding even numbers)

# %%
#Write your code below this row 👇

sum = 0 
for even in range(2, 101, 2):
    sum += even
    
print(sum)
# Out:
# 2550

# %% [markdown]
# # Ex 5.4 (FizzBuzz)

# %%
#Write your code below this row 👇

for num in range(1, 101):
    if((num%3 == 0) and (num%5 == 0)):
        print("FizzBuzz")
    elif(num%3 == 0):
        print("Fizz")
    elif(num%5 == 0):
        print("Buzz")
    else:
        print(num)
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz
# 16
# 17
# Fizz
# 19
# Buzz
# Fizz
# 22
# 23
# Fizz
# Buzz
# 26
# Fizz
# 28
# 29
# FizzBuzz
# 31
# 32
# Fizz
# 34
# Buzz
# Fizz
# 37
# 38
# Fizz
# Buzz
# 41
# Fizz
# 43
# 44
# FizzBuzz
# 46
# 47
# Fizz
# 49
# Buzz
# Fizz
# 52
# 53
# Fizz
# Buzz
# 56
# Fizz
# 58
# 59
# FizzBuzz
# 61
# 62
# Fizz
# 64
# Buzz
# Fizz
# 67
# 68
# Fizz
# Buzz
# 71
# Fizz
# 73
# 74
# FizzBuzz
# 76
# 77
# Fizz
# 79
# Buzz
# Fizz
# 82
# 83
# Fizz
# Buzz
# 86
# Fizz
# 88
# 89
# FizzBuzz
# 91
# 92
# Fizz
# 94
# Buzz
# Fizz
# 97
# 98
# Fizz
# Buzz

# %% [markdown]
# # Ex 6.1 (Hurdles Loop)

# %%
#https://reeborg.ca/reeborg.html?lang=en&mode=python&menu=worlds%2Fmenus%2Freeborg_intro_en.json&name=Hurdle%201&url=worlds%2Ftutorial_en%2Fhurdle1.json

def turn_right():
    turn_left()
    turn_left()
    turn_left()
    
def jump():
    move()
    turn_left()
    move()
    turn_right()
    move()
    turn_right()
    move()
    turn_left()
    
# hurdle 1
for i in range(6):
    jump()

# %% [markdown]
# ## Hurdle 2

# %%
while(at_goal()==0):
    jump()
    
while not at_goal():
    jump()

# %% [markdown]
# ## Hurdle 3

# %%
def jump():
    turn_left()
    move()
    turn_right()
    move()
    turn_right()
    move()
    turn_left()
    
while not at_goal():
    if (front_is_clear()== True):
        move()
    if (wall_in_front() ==True):
        jump()

# %% [markdown]
# ## Hurdle 4

# %%
while not at_goal():
    if (front_is_clear()== True and wall_on_right()):
        move() 
    elif (right_is_clear()== True):
        turn_right()
        move()
    elif(wall_in_front() ==True):
        turn_left()
        if (wall_in_front() ==True):
            turn_left()
            if (wall_in_front() ==True):
                turn_left()
            else:
                move()
        else:
            move()

# %% [markdown]
# # Ex 6.2 (Escaping the maze)

# %%
while(front_is_clear()==True):
    move()
turn_left()

while not at_goal():
    if(right_is_clear()==True):
        turn_right()
        move()
    elif(front_is_clear()==True):
        move()
    else:
        turn_left()

# %%
# Write your code below this line 👇
import math
def paint_calc(height, width, cover):
    no_of_cans = math.ceil((height*width)/cover)
    print(f"You'll need {no_of_cans} cans of paint.")

    
# Write your code above this line 👆
# Define a function called paint_calc() so that the code below works.   

# 🚨 Don't change the code below 👇
test_h = int(input("Height of wall: "))
test_w = int(input("Width of wall: "))
coverage = 5
paint_calc(height=test_h, width=test_w, cover=coverage)
# Out:
# Height of wall: 7
# Width of wall: 13
# You'll need 19 cans of paint.

# %%
#Write your code below this line 👇

def prime_checker(number):
    flag = 1
    for i in range(2,number):
        if number % i == 0:
            flag = 0        
            
    if flag == 0 :
        print("not prime")
    else:
        print("prime")



#Write your code above this line 👆
    
#Do NOT change any of the code below👇
n = int(input("Check this number: "))
prime_checker(number=n)
# Out:
# Check this number: 75
# not prime

# %%
student_scores = {
  "Harry": 81,
  "Ron": 78,
  "Hermione": 99, 
  "Draco": 74,
  "Neville": 62,
}
# 🚨 Don't change the code above 👆

#TODO-1: Create an empty dictionary called student_grades.
student_grades={}


#TODO-2: Write your code below to add the grades to student_grades.👇
for key in student_scores:
    if student_scores[key] <=100 and student_scores[key] >=91:
        student_grades[key] = "Outstanding"
    elif student_scores[key] <=90 and student_scores[key] >=81:
        student_grades[key] = "Exceeds Expectations"
    elif student_scores[key] <=80 and student_scores[key] >=71:
        student_grades[key] = "Acceptable"
    else:
        student_grades[key] = "Fail"
    

# 🚨 Don't change the code below 👇
print(student_grades)
# Out:
# {'Harry': 'Exceeds Expectations', 'Ron': 'Acceptable', 'Hermione': 'Outstanding', 'Draco': 'Acceptable', 'Neville': 'Fail'}

# %%
travel_log = [
{
  "country": "France",
  "visits": 12,
  "cities": ["Paris", "Lille", "Dijon"]
},
{
  "country": "Germany",
  "visits": 5,
  "cities": ["Berlin", "Hamburg", "Stuttgart"]
},
]
#🚨 Do NOT change the code above

#TODO: Write the function that will allow new countries
#to be added to the travel_log. 👇


def add_new_country(country, visits, city):
    log ={}
    log["country"] = country
    log["visits"] = visits
    log["cities"] = city

    travel_log.append(log)

#🚨 Do not change the code below
add_new_country("Russia", 2, ["Moscow", "Saint Petersburg"])
print(travel_log)
print(travel_log[2])
# Out:
# [{'country': 'France', 'visits': 12, 'cities': ['Paris', 'Lille', 'Dijon']}, {'country': 'Germany', 'visits': 5, 'cities': ['Berlin', 'Hamburg', 'Stuttgart']}, {'country': 'Russia', 'visits': 2, 'cities': ['Moscow', 'Saint Petersburg']}]
# {'country': 'Russia', 'visits': 2, 'cities': ['Moscow', 'Saint Petersburg']}

# %% [markdown]
# # Ex 10.1 Days in a month

# %%
def is_leap(year):
    if year % 4 == 0:
        if year % 100 == 0:
            if year % 400 == 0:
                return True
            else:
                return False
        else:
            return True
    else:
        return False

def days_in_month(year, month):
    month_days = [31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31] 
    Leap_true = is_leap(year)
    
    if Leap_true:
        if month == 2:
            return 29
        else:
            return month_days[month-1]
    else:
        return month_days[month-1]
  
  
#🚨 Do NOT change any of the code below 
year = int(input("Enter a year: "))
month = int(input("Enter a month: "))
days = days_in_month(year, month)
print(days)
# Out:
# Enter a year: 2022
# Enter a month: 2
# 28

# %% [markdown]
# # Ex 13.1 (Debugging odd or even)

# %%
# Problem
# number = int(input("Which number do you want to check?"))
# if number % 2 = 0:
#   print("This is an even number.")
# else:
#   print("This is an odd number.")


# Solution
number = int(input("Which number do you want to check?"))
if number % 2 == 0:
  print("This is an even number.")
else:
  print("This is an odd number.")
# Out:
# Which number do you want to check?9
# This is an odd number.

# %% [markdown]
# # Ex 13.2 (Debugging Leap year)

# %%
# Problem
# year = input("Which year do you want to check?")
# if year % 4 == 0:
#   if year % 100 == 0:
#     if year % 400 == 0:
#       print("Leap year.")
#     else:
#       print("Not leap year.")
#   else:
#     print("Leap year.")
# else:
#   print("Not leap year.")


# Solution 
year = int(input("Which year do you want to check?"))
if year % 4 == 0:
  if year % 100 == 0:
    if year % 400 == 0:
      print("Leap year.")
    else:
      print("Not leap year.")
  else:
    print("Leap year.")
else:
  print("Not leap year.")
# Out:
# Which year do you want to check?2000
# Leap year.

# %% [markdown]
# # Ex 13.3 (Debugging FizzBuzz)

# %%
# Problem
# for number in range(1, 101):
#   if number % 3 == 0 or number % 5 == 0:
#     print("FizzBuzz")
#   if number % 3 == 0:
#     print("Fizz")
#   if number % 5 == 0:
#     print("Buzz")
#   else:
#     print([number])
    
# Solution    
for number in range(1, 101):
  if number % 3 == 0 and number % 5 == 0:
    print("FizzBuzz")
  elif number % 3 == 0:
    print("Fizz")
  elif number % 5 == 0:
    print("Buzz")
  else:
    print(number)
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz
# 16
# 17
# Fizz
# 19
# Buzz
# Fizz
# 22
# 23
# Fizz
# Buzz
# 26
# Fizz
# 28
# 29
# FizzBuzz
# 31
# 32
# Fizz
# 34
# Buzz
# Fizz
# 37
# 38
# Fizz
# Buzz
# 41
# Fizz
# 43
# 44
# FizzBuzz
# 46
# 47
# Fizz
# 49
# Buzz
# Fizz
# 52
# 53
# Fizz
# Buzz
# 56
# Fizz
# 58
# 59
# FizzBuzz
# 61
# 62
# Fizz
# 64
# Buzz
# Fizz
# 67
# 68
# Fizz
# Buzz
# 71
# Fizz
# 73
# 74
# FizzBuzz
# 76
# 77
# Fizz
# 79
# Buzz
# Fizz
# 82
# 83
# Fizz
# Buzz
# 86
# Fizz
# 88
# 89
# FizzBuzz
# 91
# 92
# Fizz
# 94
# Buzz
# Fizz
# 97
# 98
# Fizz
# Buzz
