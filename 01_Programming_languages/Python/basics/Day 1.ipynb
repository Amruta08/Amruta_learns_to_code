# %% [markdown]
#  ## Day 1

# %%
print("Hello, world!")
# print tells what to print
# "" , '' --> represent string
# Out:
# Hello, world!

# %% [markdown]
# # Exercise 1.1

# %%
print("Day 1 - Python Print Function")
print("The function is declared like this:")
print("print('what to print')")
# Out:
# Day 1 - Python Print Function
# The function is declared like this:
# print('what to print')

# %% [markdown]
# ## ----------------------------------------------------------------------------------------------------------------------------------

# %%
print("hello'world'")
print("hello\nworld")
print("hello"+ " name")

#errors discussed --> syntax , indentation
# Out:
# hello'world'
# hello
# world
# hello name
