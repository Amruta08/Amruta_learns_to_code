# %%
print("***********************")
print("hellol")
print("***********************")
print("enter your name")
print("***********************")
# Out:
# ***********************
# hellol
# ***********************
# enter your name
# ***********************

# %%
def displaystar():
    print("***********************")
    
displaystar()
print("hellol")
displaystar()

displaystar()
displaystar()
displaystar()
# Out:
# ***********************
# hellol
# ***********************
# ***********************
# ***********************
# ***********************

# %%
def displaystar():
    print("***********************")

# %%
def display():
    print('my name')
    
    
display()
display()
display()
# Out:
# my name
# my name
# my name

# %%
def greet(name):
    print("Hello " + name)
    

user = input("Enter your name ")    
greet(user)
# Out:
# Enter your name as
# Hello as

# %%
def armstrong(num):
    temp = num
    summ = 0
    
    while (temp>0):
        digit = temp%10
        summ += digit**3
        temp//= 10
        
        if (num == summ):
            print("armstrong number")
        else:
            print("not armstrong")

            
no = int(input("Enter number"))
armstrong(no)
# Out:
# Enter number153
# not armstrong
# not armstrong
# armstrong number

# %%
class rectangle:
    def __init__(self,breadth,length):
        self.length = length
        self.breadth = breadth
        
        
    def area(self):
        return self.length*self.breadth
        
a = int(input("enter length "))
b = int(input("enter breadth "))

obj = rectangle(a,b)

print(f"area of rectangle =  {obj.area()}")
# Out:
# enter length 2
# enter breadth 3
# area of rectangle =  6

# %%
class circle:
    def __init__(self,radius):
        self.radius = radius
        
        
    def circumference(self):
        return 2*3.14*self.radius
    

a=int(input("enter radius"))

obj = circle(a)

print(f"circumference of circle = {obj.circumference()}")
# Out:
# enter radius4
# circumference of circle = 25.12
