# %% [markdown]
# # Secret Auction

# %%
# key --> Bider's name
# Value --> amount  bid by bider
# What is your name?: james
# What's your bid?: $345

# from replit import clear

from IPython.display import clear_output

from artAuction import logo
print(logo)

#HINT: You can call clear() to clear the output in the console.
result = []
auction={}

move_ahead = 'yes'
print("Welcome to the secret auction program")
while move_ahead == 'yes':
    clear_output(wait=True)
    bider = input("What is your name?: ")
    bid = int(input("What's your bid?: $"))

    auction[bider] = bid
#     result.append(auction)

    move_ahead = input("Are there are any other bidders? Type 'yes' or 'no'.\n").lower()
    clear_output(wait=True)

maximum = 0
for key in auction:
    if auction[key] > maximum:
        maximum = auction[key]
        maxkey = key

# print(auction)
print(f"The winner is {maxkey} with a bid of ${maximum}")
# Out:
# The winner is james with a bid of $142
