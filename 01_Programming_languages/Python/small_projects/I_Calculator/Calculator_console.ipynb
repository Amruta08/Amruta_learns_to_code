# %%
# Calculotor

# TODO 1 :- Display logo

# TODO 2 :- Create functions for add, sub, mul and divide,
# They should take 2 numbers and return the respective result.

# TODO 3 :- Create a dictionary operations where operators are keys
# and values are function names

# TODO 4:- Ask user for the 1st number

# TODO 5:- Loop through the dictionary and print the keys

# TODO 6:- Ask user to pick an operation and enter 2nd number

# TODO 7:- Using the operation that the user requested 
# call the required function and display the output

# TODO 8 :- Use a while loop to continue calculating 

# TODO 9 :- Use recursion to start a new calculation

# %%
# Displaying logo
from art import logo


# Add
def add(n1, n2):
    return n1+n2

# Subtract
def subtract(n1, n2):
    return n1-n2

# Multiply
def multiply(n1, n2):
    return n1*n2

# Divide
def divide(n1, n2):
    return n1/n2

operations={
    '+':add,
    '-':subtract,
    '*':multiply,
    '/':divide,
    
}

calculator()

def calculator():
    print(logo)
    num1 = float(input("What's the first number ?: "))

    for key in operations:
        print(key)

    proceed = 'y'

    while (proceed == 'y'):
        operator = input("Pick an operation: ")
        num2 = float(input("What's the next number ?: "))

        function = operations[operator]
        result = function(num1, num2)
        print(f"{num1} {operator} {num2} = {result}")

        proceed = input(f"Type 'y' to continue calculating with {result}, or type 'n' to start a new calculation. or exit to exit: ")

        if proceed == 'y':
            num1 = result
        elif proceed == 'n':
            calculator()
        else:
            return
            
        

# operator = input("Pick another operation: ")
# num3 = int(input("What's the next number ?: "))

# function = operations[operator]
# result2 = function(result1, num3)
# print(f"{result1} {operator} {num3} = {result2}")
# Out:
#  _____________________
# |  _________________  |
# | | Pythonista   0. | |  .----------------.  .----------------.  .----------------.  .----------------.
# | |_________________| | | .--------------. || .--------------. || .--------------. || .--------------. |
# |  ___ ___ ___   ___  | | |     ______   | || |      __      | || |   _____      | || |     ______   | |
# | | 7 | 8 | 9 | | + | | | |   .' ___  |  | || |     /  \     | || |  |_   _|     | || |   .' ___  |  | |
# | |___|___|___| |___| | | |  / .'   \_|  | || |    / /\ \    | || |    | |       | || |  / .'   \_|  | |
# | | 4 | 5 | 6 | | - | | | |  | |         | || |   / ____ \   | || |    | |   _   | || |  | |         | |
# | |___|___|___| |___| | | |  \ `.___.'\  | || | _/ /    \ \_ | || |   _| |__/ |  | || |  \ `.___.'\  | |
# | | 1 | 2 | 3 | | x | | | |   `._____.'  | || ||____|  |____|| || |  |________|  | || |   `._____.'  | |
# ...
