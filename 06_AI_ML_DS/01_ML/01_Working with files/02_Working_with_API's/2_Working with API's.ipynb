# %%
import pandas as pd
import requests

# %%
url = "https://www.deckofcardsapi.com/api/deck/new/shuffle/?deck_count=1"
response = requests.get(url)
response.json()
# Out:
# {'success': True, 'deck_id': 'misarvqz42pw', 'remaining': 52, 'shuffled': True}

# %%
response.json()['success']
# Out:
# True

# %%
# Convert the json into a DataFrame, but a list needs to be passed
df = pd.DataFrame([response.json()])
df
# Out:
#    success       deck_id  remaining  shuffled
# 0     True  misarvqz42pw         52      True

# %%
df = pd.DataFrame([response.json()])[['deck_id', 'remaining']]
df
# Out:
#         deck_id  remaining
# 0  misarvqz42pw         52

# %%
df = pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1, 4):
    res = requests.get(url)
    temp_df = pd.DataFrame([response.json()])[['deck_id', 'remaining']]
    df = df.append(temp_df)

# %%
df
# Out:
#         deck_id  remaining
# 0  misarvqz42pw         52
# 0  misarvqz42pw         52
# 0  misarvqz42pw         52

# %%
# Converting dataframe into a csv file
df.to_csv('p.csv')

# %%
df = pd.read_csv('p.csv')
df
# Out:
#    Unnamed: 0       deck_id  remaining
# 0           0  misarvqz42pw         52
# 1           0  misarvqz42pw         52
# 2           0  misarvqz42pw         52
