# %%
# Loading dataset
import pandas as pd
import numpy as np
df = pd.read_csv("train.csv", usecols=['GarageQual','FireplaceQu','SalePrice'])
df.head()
# Out:
#   FireplaceQu GarageQual  SalePrice
# 0         NaN         TA     208500
# 1          TA         TA     181500
# 2          TA         TA     223500
# 3          Gd         TA     140000
# 4          TA         TA     250000

# %%
# Finding % of missing values
df.isnull().mean()*100
# Out:
# FireplaceQu    47.260274
# GarageQual      5.547945
# SalePrice       0.000000
# dtype: float64

# %% [markdown]
# # Using Pandas

# %%
# Plotting countplot of GarageQual
import seaborn as sns
sns.countplot(df['GarageQual'])
# Out:
# <Axes: xlabel='count', ylabel='GarageQual'>

# %%
# "Missing" Imputation
df['GarageQual'] = df['GarageQual'].fillna('Missing')

# %%
# Plotting countplot of GarageQual after "Missing" Imputation
sns.countplot(df['GarageQual'])
# Out:
# <Axes: xlabel='count', ylabel='GarageQual'>

# %% [markdown]
# # Using sklearn

# %%
# Train test split
from sklearn.model_selection import train_test_split
X = df.drop(['SalePrice'], axis=1)
Y = df['SalePrice']

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)

# %%
# Sklearn simpleImputer
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='constant', fill_value='Missing')

# %%
X_train = imputer.fit_transform(X_train)
X_test = imputer.transform(X_test)

# %%
imputer.statistics_
# Out:
# array(['Missing', 'Missing'], dtype=object)
