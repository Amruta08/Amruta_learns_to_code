# %%
# Load data
import pandas as pd
import numpy as np
df = pd.read_csv('income.csv')
df.head()
# Out:
#    year       income
# 0  1970  3399.299037
# 1  1971  3768.297935
# 2  1972  4251.175484
# 3  1973  4804.463248
# 4  1974  5576.514583

# %%
# Plotting the scatter plot
import matplotlib.pyplot as plt
plt.xlabel('year')
plt.ylabel('per captia income')
plt.scatter(df.year, df.income)

# %%
# Apply linear regression
from sklearn.linear_model import LinearRegression

# Create object of linear regresstion class
reg = LinearRegression()

# fitting data/training linear regression model
reg.fit(df[['year']], df.income)
# Out:
# LinearRegression()

# %%
# Plotting line of best fit
plt.xlabel('year')
plt.ylabel('per captia income')
plt.scatter(df.year, df.income)
plt.plot(df.year, reg.predict(df[['year']]))

# %%
# Predict year income in year 2020
reg.predict([[2020]])
# Out:
# C:\Users\Amruta\anaconda3\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442])
