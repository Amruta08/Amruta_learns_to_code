# %% [markdown]
# #Word2vec on google-news

# %%
# !pip install gensim
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.12/dist-packages (4.4.0)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from gensim) (2.0.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from gensim) (1.16.3)
# Requirement already satisfied: smart_open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim) (7.4.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart_open>=1.8.1->gensim) (2.0.0)

# %%
# Loading the pretrained word2vec model
import gensim.downloader as api
model = api.load('word2vec-google-news-300')
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded

# %%
# Shows vector representation of word 'man'
model['man']
# Out:
# array([ 0.32617188,  0.13085938,  0.03466797, -0.08300781,  0.08984375,
#        -0.04125977, -0.19824219,  0.00689697,  0.14355469,  0.0019455 ,
#         0.02880859, -0.25      , -0.08398438, -0.15136719, -0.10205078,
#         0.04077148, -0.09765625,  0.05932617,  0.02978516, -0.10058594,
#        -0.13085938,  0.001297  ,  0.02612305, -0.27148438,  0.06396484,
#        -0.19140625, -0.078125  ,  0.25976562,  0.375     , -0.04541016,
#         0.16210938,  0.13671875, -0.06396484, -0.02062988, -0.09667969,
#         0.25390625,  0.24804688, -0.12695312,  0.07177734,  0.3203125 ,
#         0.03149414, -0.03857422,  0.21191406, -0.00811768,  0.22265625,
#        -0.13476562, -0.07617188,  0.01049805, -0.05175781,  0.03808594,
#        -0.13378906,  0.125     ,  0.0559082 , -0.18261719,  0.08154297,
#        -0.08447266, -0.07763672, -0.04345703,  0.08105469, -0.01092529,
#         0.17480469,  0.30664062, -0.04321289, -0.01416016,  0.09082031,
#        -0.00927734, -0.03442383, -0.11523438,  0.12451172, -0.0246582 ,
#         0.08544922,  0.14355469, -0.27734375,  0.03662109, -0.11035156,
#         0.13085938, -0.01721191, -0.08056641, -0.00708008, -0.02954102,
#         0.30078125, -0.09033203,  0.03149414, -0.18652344, -0.11181641,
#         0.10253906, -0.25976562, -0.02209473,  0.16796875, -0.05322266,
#        -0.14550781, -0.01049805, -0.03039551, -0.03857422,  0.11523438,
#        -0.0062561 , -0.13964844,  0.08007812,  0.06103516, -0.15332031,
#        -0.11132812, -0.14160156,  0.19824219, -0.06933594,  0.29296875,
#        -0.16015625,  0.20898438,  0.00041771,  0.01831055, -0.20214844,
#         0.04760742,  0.05810547, -0.0123291 , -0.01989746, -0.00364685,
#        -0.0135498 , -0.08251953, -0.03149414,  0.00717163,  0.20117188,
#         0.08300781, -0.0480957 , -0.26367188, -0.09667969, -0.22558594,
#        -0.09667969,  0.06494141, -0.02502441,  0.08496094,  0.03198242,
#        -0.07568359, -0.25390625, -0.11669922, -0.01446533, -0.16015625,
#        -0.00701904, -0.05712891,  0.02807617, -0.09179688,  0.25195312,
#         0.24121094,  0.06640625,  0.12988281,  0.17089844, -0.13671875,
#         0.1875    , -0.10009766, -0.04199219, -0.12011719,  0.00524902,
#         0.15625   , -0.203125  , -0.07128906, -0.06103516,  0.01635742,
#         0.18261719,  0.03588867, -0.04248047,  0.16796875, -0.15039062,
#        -0.16992188,  0.01831055,  0.27734375, -0.01269531, -0.0390625 ,
#        -0.15429688,  0.18457031, -0.07910156,  0.09033203, -0.02709961,
#         0.08251953,  0.06738281, -0.16113281, -0.19628906, -0.15234375,
#        -0.04711914,  0.04760742,  0.05908203, -0.16894531, -0.14941406,
#         0.12988281,  0.04321289,  0.02624512, -0.1796875 , -0.19628906,
#         0.06445312,  0.08935547,  0.1640625 , -0.03808594, -0.09814453,
#        -0.01483154,  0.1875    ,  0.12792969,  0.22753906,  0.01818848,
#        -0.07958984, -0.11376953, -0.06933594, -0.15527344, -0.08105469,
#        -0.09277344, -0.11328125, -0.15136719, -0.08007812, -0.05126953,
#        -0.15332031,  0.11669922,  0.06835938,  0.0324707 , -0.33984375,
#        -0.08154297, -0.08349609,  0.04003906,  0.04907227, -0.24121094,
#        -0.13476562, -0.05932617,  0.12158203, -0.34179688,  0.16503906,
#         0.06176758, -0.18164062,  0.20117188, -0.07714844,  0.1640625 ,
#         0.00402832,  0.30273438, -0.10009766, -0.13671875, -0.05957031,
#         0.0625    , -0.21289062, -0.06542969,  0.1796875 , -0.07763672,
#        -0.01928711, -0.15039062, -0.00106049,  0.03417969,  0.03344727,
#         0.19335938,  0.01965332, -0.19921875, -0.10644531,  0.01525879,
#         0.00927734,  0.01416016, -0.02392578,  0.05883789,  0.02368164,
#         0.125     ,  0.04760742, -0.05566406,  0.11572266,  0.14746094,
#         0.1015625 , -0.07128906, -0.07714844, -0.12597656,  0.0291748 ,
#         0.09521484, -0.12402344, -0.109375  , -0.12890625,  0.16308594,
#         0.28320312, -0.03149414,  0.12304688, -0.23242188, -0.09375   ,
#        -0.12988281,  0.0135498 , -0.03881836, -0.08251953,  0.00897217,
#         0.16308594,  0.10546875, -0.13867188, -0.16503906, -0.03857422,
#         0.10839844, -0.10498047,  0.06396484,  0.38867188, -0.05981445,
#        -0.0612793 , -0.10449219, -0.16796875,  0.07177734,  0.13964844,
#         0.15527344, -0.03125   , -0.20214844, -0.12988281, -0.10058594,
#        -0.06396484, -0.08349609, -0.30273438, -0.08007812,  0.02099609],
#       dtype=float32)

# %%
# vector contains 300 numbers
model['man'].shape
# Out:
# (300,)

# %%
# Shows words which are similar/related to 'man' vector
model.most_similar('man')
# Out:
# [('woman', 0.7664012908935547),
#  ('boy', 0.6824871301651001),
#  ('teenager', 0.6586930155754089),
#  ('teenage_girl', 0.6147903203964233),
#  ('girl', 0.5921714305877686),
#  ('suspected_purse_snatcher', 0.571636438369751),
#  ('robber', 0.5585119128227234),
#  ('Robbery_suspect', 0.5584409832954407),
#  ('teen_ager', 0.5549196600914001),
#  ('men', 0.5489763021469116)]

# %%
# Shows cosine similarity between 'man' & 'woman'
model.similarity('man', 'woman')
# Out:
# np.float32(0.76640123)

# %%
# Shows the odd one out (here monkey)
model.doesnt_match(['PHP','java','monkey'])
# Out:
# 'monkey'

# %%
# Vector arithmetic
vec = model['king'] - model['man'] + model['women']
model.most_similar([vec])
# Out:
# [('king', 0.6478992700576782),
#  ('queen', 0.535493791103363),
#  ('women', 0.5233659148216248),
#  ('kings', 0.5162314772605896),
#  ('queens', 0.4995364248752594),
#  ('kumaris', 0.49238473176956177),
#  ('princes', 0.46233269572257996),
#  ('monarch', 0.45280295610427856),
#  ('monarchy', 0.4293173849582672),
#  ('kings_princes', 0.42342400550842285)]

# %% [markdown]
# # Word2Vec on Game of thrones books dataset

# %%
import nltk
nltk.download('punkt_tab')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Function to remove stopwords
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))

def remove_stopwords(text):
    new_text = []
    for word in text.split():
        if word not in stop_words:
            new_text.append(word)
    return " ".join(new_text)

# %%
import os
import gensim
from nltk import sent_tokenize
from gensim.utils import simple_preprocess

story = []
for filename in os.listdir('books'):
    # Open text files present in books directory
    f = open(os.path.join('books', filename), encoding='latin-1')
    # Store text content of file in corpus
    corpus = f.read()
    # Perform Sentence tokenization on the corpus of text
    raw_sent = sent_tokenize(corpus)
    # add the sentences in the story list by performing some simple preprocessing and removing stopwords
    for sent in raw_sent:
      sent = remove_stopwords(sent)
      story.append(simple_preprocess(sent))

# %%
print(story[0])
# Out:
# ['game', 'of', 'thrones', 'book', 'one', 'song', 'ice', 'fire', 'by', 'george', 'martin', 'prologue', 'we', 'start', 'back', 'gared', 'urged', 'woods', 'began', 'grow', 'dark', 'around', 'them']

# %%
# Creating the Word2Vec model
model = gensim.models.Word2Vec(
    window=10, #window size
    min_count=2, #sentences should have min 2 words
)

# Extracting unique words form corpus using build_vocab function
model.build_vocab(story)

# Training the deep learning model
model.train(story, total_examples=model.corpus_count, epochs=model.epochs)
# Out:
# (4996082, 5308310)

# %%
# Checking words similar to daenerys
model.wv.most_similar('daenerys')
# Out:
# [('stormborn', 0.8643744587898254),
#  ('targaryen', 0.8311626315116882),
#  ('unburnt', 0.8171461224555969),
#  ('queen', 0.8155773282051086),
#  ('dorne', 0.7992861866950989),
#  ('myrcella', 0.7990050315856934),
#  ('adultery', 0.791711688041687),
#  ('princess', 0.7777925133705139),
#  ('elia', 0.7746576070785522),
#  ('viserys', 0.7615095973014832)]

# %%
# Checking odd man out
model.wv.doesnt_match(['jon', 'rikon', 'robb', 'arya', 'sansa', 'bran'])
# Out:
# WARNING:gensim.models.keyedvectors:vectors for words {'rikon'} are not present in the model, ignoring these words
# 'jon'

# %%
# Checking odd man out
model.wv.doesnt_match(['cersei', 'jaime', 'bronn', 'tyrion'])
# Out:
# 'bronn'

# %%
# Checking vector representation of jon
model.wv['jon']
# Out:
# array([-0.37333268,  1.7559718 ,  1.67618   ,  2.3724275 , -0.6911467 ,
#         0.1577172 , -1.402629  ,  0.7841473 ,  0.26537195, -1.7736396 ,
#        -0.34880686, -0.8164014 ,  0.6294275 ,  0.16258931, -3.0746145 ,
#        -0.96327513,  2.7218907 , -2.1940055 ,  0.8365205 ,  0.1791577 ,
#         0.00960632, -1.5814421 , -0.12501015,  1.2620187 ,  2.102936  ,
#         0.6265236 , -1.1301401 ,  1.0289282 ,  1.5124362 ,  1.040278  ,
#         0.985531  , -1.0007259 ,  1.5073858 , -1.9560288 , -0.20401745,
#        -0.39278445,  1.878159  , -0.10580686, -0.2741514 , -0.9786446 ,
#        -0.31285724,  0.7454806 ,  0.7772452 , -0.9364487 , -0.8988815 ,
#        -1.3085512 , -0.27379122, -0.35242218, -1.6736205 ,  0.0251095 ,
#        -0.21426958,  0.502376  , -2.552921  ,  1.6141907 , -1.1325587 ,
#        -1.3693942 ,  0.42351422,  0.06166199, -1.462749  , -0.1320718 ,
#        -0.45961168,  0.47507977,  0.10000948,  1.722399  ,  0.32052237,
#         0.20580088,  1.7583212 ,  0.49775842, -0.2500746 ,  0.03299017,
#         0.96642107,  1.3185116 ,  0.92149574, -0.67721033,  0.07200942,
#        -3.303732  , -1.3591835 ,  0.67686176,  0.82067883,  0.5768686 ,
#        -1.2250804 , -0.42036876,  1.0936904 ,  1.1505044 , -1.5249265 ,
#        -0.08586891,  0.37146363, -0.5320201 ,  0.16204384,  0.9221528 ,
#         1.2630937 ,  0.08318372, -0.37161216,  0.1146532 , -0.71563864,
#         0.37766787, -0.47840786, -0.0784573 , -0.7276069 ,  1.4480462 ],
#       dtype=float32)

# %%
# Checking similarity between arya & sansa
model.wv.similarity('arya', 'sansa') #0.83077496
# Out:
# np.float32(0.79935926)

# %%
# Get vector representation of all the words
model.wv.get_normed_vectors()
# Out:
# array([[ 0.00593347,  0.00887729,  0.09464634, ..., -0.04558886,
#         -0.11038836,  0.03785123],
#        [-0.08932988,  0.10151627,  0.10917999, ..., -0.05245783,
#         -0.11135022,  0.08939289],
#        [-0.0182923 ,  0.0746931 , -0.11632224, ...,  0.08262765,
#          0.06957389, -0.1621232 ],
#        ...,
#        [-0.08539195,  0.12631853,  0.02866963, ..., -0.12534562,
#         -0.03856654,  0.05141809],
#        [-0.00860489,  0.11817105,  0.08698175, ..., -0.05211031,
#         -0.08067939,  0.00346928],
#        [ 0.00604317,  0.0601439 ,  0.0366868 , ...,  0.09437905,
#          0.0288917 ,  0.01628141]], dtype=float32)

# %%
# Get the word corresponding to each vector representation
y = model.wv.index_to_key
y
# Out:
# ['the',
#  'he',
#  'said',
#  'lord',
#  'you',
#  'it',
#  'would',
#  'one',
#  'ser',
#  'him',
#  'she',
#  'could',
#  'man',
#  'her',
#  'that',
#  'king',
#  'men',
#  'back',
#  'and',
#  'well',
#  'like',
#  'jon',
#  'me',
#  'them',
#  'they',
#  'his',
#  'father',
#  'old',
#  'hand',
#  'even',
#  'tyrion',
#  'never',
#  'know',
#  'see',
#  'there',
#  'made',
#  'eyes',
#  'black',
#  'told',
#  'lady',
#  'thought',
#  'no',
#  'if',
#  'time',
#  'long',
#  'might',
#  'us',
#  'come',
#  'we',
#  'face',
#  'still',
#  'when',
#  'head',
#  'red',
#  'way',
#  'boy',
#  'page',
#  'but',
#  'must',
#  'queen',
#  'good',
#  'two',
#  'brother',
#  'night',
#  'little',
#  'took',
#  'came',
#  'though',
#  'say',
#  'now',
#  'three',
#  'what',
#  'away',
#  'dead',
#  'my',
#  'son',
#  'blood',
#  'take',
#  'go',
#  'your',
#  'half',
#  'make',
#  'this',
#  'arya',
#  'll',
#  'saw',
#  'all',
#  'day',
#  'white',
#  'jaime',
#  'first',
#  'look',
#  'want',
#  'much',
#  'enough',
#  'sword',
#  'tell',
#  'girl',
#  'bran',
#  'great',
#  'again',
#  'looked',
#  'left',
#  'knew',
#  'asked',
#  'gave',
#  'maester',
#  'called',
#  'wall',
#  'every',
#  'heard',
#  'sansa',
#  'let',
#  'yet',
#  'here',
#  'went',
#  'not',
#  'turned',
#  'dany',
#  'need',
#  'behind',
#  'around',
#  'woman',
#  'another',
#  'then',
#  'snow',
#  'beneath',
#  'across',
#  'knight',
#  'so',
#  'keep',
#  'do',
#  'grace',
#  'found',
#  'gold',
#  'last',
#  'cersei',
#  'castle',
#  'stark',
#  'gods',
#  'too',
#  'think',
#  'hair',
#  'many',
#  'feet',
#  'hands',
#  'stannis',
#  'mother',
#  'as',
#  'in',
#  'catelyn',
#  'robert',
#  'seemed',
#  'prince',
#  'may',
#  'ever',
#  'robb',
#  'done',
#  'find',
#  'lannister',
#  'hear',
#  'name',
#  'grey',
#  'horse',
#  'high',
#  'put',
#  'stone',
#  'wine',
#  'hard',
#  'water',
#  'upon',
#  'fire',
#  'iron',
#  'voice',
#  'gone',
#  'give',
#  'sam',
#  'better',
#  'seen',
#  'shall',
#  'ned',
#  'always',
#  'years',
#  'dark',
#  'is',
#  'place',
#  'small',
#  'cold',
#  'winterfell',
#  'hundred',
#  'how',
#  'stood',
#  'end',
#  'sister',
#  'once',
#  'did',
#  'words',
#  'sea',
#  'right',
#  'for',
#  'nothing',
#  'walls',
#  'fingers',
#  'house',
#  'cloak',
#  'young',
#  'beside',
#  'get',
#  'out',
#  'seven',
#  'mouth',
#  'watch',
#  'door',
#  'joffrey',
#  'green',
#  'big',
#  'why',
#  'sent',
#  'on',
#  'perhaps',
#  'almost',
#  'wanted',
#  'daughter',
#  'true',
#  'leave',
#  'city',
#  'wind',
#  'light',
#  'arms',
#  'children',
#  'sweet',
#  'others',
#  'lost',
#  'was',
#  'theon',
#  'felt',
#  'side',
#  'yes',
#  'brothers',
#  'best',
#  'to',
#  'die',
#  'brought',
#  'soon',
#  'up',
#  'died',
#  'far',
#  'north',
#  'child',
#  'fear',
#  'along',
#  'brienne',
#  'word',
#  'taken',
#  'will',
#  'battle',
#  'help',
#  'at',
#  'new',
#  'tywin',
#  'davos',
#  'lords',
#  're',
#  'something',
#  'mean',
#  'wife',
#  'more',
#  'some',
#  'hall',
#  'rest',
#  'kill',
#  'who',
#  'strong',
#  'steel',
#  'began',
#  'be',
#  'sound',
#  'dragon',
#  'past',
#  'life',
#  'tower',
#  'killed',
#  'arm',
#  'tried',
#  'sons',
#  'free',
#  'thing',
#  'bear',
#  'days',
#  'bloody',
#  'heart',
#  'pale',
#  'love',
#  'moment',
#  'sat',
#  'bring',
#  'bed',
#  'by',
#  'close',
#  'knights',
#  'cut',
#  'wolf',
#  'death',
#  'horses',
#  'smile',
#  'inside',
#  'four',
#  'brown',
#  'dragons',
#  'hot',
#  'silver',
#  'part',
#  'bastard',
#  'open',
#  'thousand',
#  'landing',
#  'uncle',
#  'going',
#  'blue',
#  'captain',
#  'air',
#  'please',
#  'laughed',
#  'river',
#  'sun',
#  'rose',
#  'fell',
#  'down',
#  'war',
#  'can',
#  'golden',
#  'sleep',
#  'without',
#  'swords',
#  'renly',
#  'speak',
#  'certain',
#  'fool',
#  'full',
#  'only',
#  'beyond',
#  'feel',
#  'send',
#  've',
#  'tongue',
#  'fight',
#  'got',
#  'set',
#  'rode',
#  'thick',
#  'world',
#  'throat',
#  'are',
#  'legs',
#  'deep',
#  'call',
#  'himself',
#  'honor',
#  'rock',
#  'trees',
#  'tall',
#  'table',
#  'pulled',
#  'broken',
#  'women',
#  'mormont',
#  'before',
#  'steps',
#  'off',
#  'things',
#  'next',
#  'or',
#  'hodor',
#  'heavy',
#  'burned',
#  'oh',
#  'toward',
#  'together',
#  'skin',
#  'given',
#  'since',
#  'dwarf',
#  'alone',
#  'moved',
#  'smiled',
#  'storm',
#  'raised',
#  'of',
#  'ask',
#  'ride',
#  'eye',
#  'hope',
#  'reached',
#  'soft',
#  'frey',
#  'second',
#  'remember',
#  'someone',
#  'remembered',
#  'coming',
#  'meant',
#  'cannot',
#  'hold',
#  'morning',
#  'ten',
#  'teeth',
#  'else',
#  'throne',
#  'command',
#  'fat',
#  'truth',
#  'walder',
#  'with',
#  'commander',
#  'doubt',
#  'ground',
#  'jorah',
#  'cup',
#  'outside',
#  'known',
#  'wore',
#  'ran',
#  'don',
#  'gate',
#  'room',
#  'held',
#  'closed',
#  'home',
#  'matter',
#  'south',
#  'wood',
#  'sky',
#  'have',
#  'wed',
#  'people',
#  'dozen',
#  'neck',
#  'food',
#  'riverrun',
#  'instead',
#  'near',
#  'turn',
#  'talk',
#  'none',
#  'ships',
#  'where',
#  'tyrell',
#  'moon',
#  'bolton',
#  'lips',
#  'summer',
#  'shadow',
#  'watched',
#  'times',
#  'leather',
#  'varys',
#  'shoulder',
#  'septon',
#  'warm',
#  'caught',
#  'believe',
#  'least',
#  'guards',
#  'answer',
#  'god',
#  'blade',
#  'wondered',
#  'ice',
#  'barristan',
#  'shield',
#  'mine',
#  'opened',
#  'armor',
#  'safe',
#  'six',
#  'kept',
#  'return',
#  'wish',
#  'tommen',
#  'used',
#  'smell',
#  'other',
#  'less',
#  'foot',
#  'squire',
#  'floor',
#  'eddard',
#  'empty',
#  'run',
#  'followed',
#  'serve',
#  'friends',
#  'boys',
#  'beard',
#  'wedding',
#  'cloaks',
#  'baratheon',
#  'eat',
#  'wrong',
#  'daenerys',
#  'ghost',
#  'sight',
#  'hound',
#  'five',
#  'flesh',
#  'ship',
#  'strength',
#  'nose',
#  'returned',
#  'bones',
#  'crown',
#  'yellow',
#  'chest',
#  'covered',
#  'commanded',
#  'says',
#  'petyr',
#  'their',
#  'sometimes',
#  'filled',
#  'aemon',
#  'led',
#  'friend',
#  'aye',
#  'common',
#  'flames',
#  'show',
#  'fighting',
#  'spoke',
#  'after',
#  'asha',
#  'aside',
#  'lysa',
#  'huge',
#  'crow',
#  'belly',
#  'master',
#  'seem',
#  'breath',
#  'yard',
#  'gates',
#  'waiting',
#  'within',
#  'looking',
#  'wooden',
#  'wet',
#  'herself',
#  'realm',
#  'thin',
#  'work',
#  'bad',
#  'promised',
#  'use',
#  'husband',
#  'grew',
#  'tree',
#  'later',
#  'onto',
#  'loved',
#  'wildlings',
#  'girls',
#  'greyjoy',
#  'afraid',
#  'rain',
#  'shoulders',
#  'from',
#  'walked',
#  'shouted',
#  'maid',
#  'remained',
#  'mance',
#  'late',
#  'guard',
#  'meereen',
#  'littlefinger',
#  'liked',
#  'fall',
#  'margaery',
#  'dog',
#  'year',
#  'hurt',
#  'passed',
#  'balon',
#  'taste',
#  'dothraki',
#  'drew',
#  'lay',
#  'spear',
#  'realized',
#  'pushed',
#  'song',
#  'named',
#  'sure',
#  'stand',
#  'reach',
#  'brave',
#  'finally',
#  'whispered',
#  'different',
#  'wolves',
#  'suddenly',
#  'poor',
#  'kingsguard',
#  'drogo',
#  'stay',
#  'arryn',
#  'stop',
#  'kingdoms',
#  'edmure',
#  'broke',
#  'ears',
#  'princess',
#  'burning',
#  'faces',
#  'lannisters',
#  'dream',
#  'direwolf',
#  'axe',
#  'west',
#  'heir',
#  'tears',
#  'drink',
#  'clegane',
#  'either',
#  'darkness',
#  'raven',
#  'pointed',
#  'hill',
#  'try',
#  'forward',
#  'pain',
#  'sworn',
#  'khal',
#  'lie',
#  'dagger',
#  'truly',
#  'kings',
#  'seat',
#  'grown',
#  'road',
#  'born',
#  'harrenhal',
#  'care',
#  'bronn',
#  'same',
#  'helm',
#  'round',
#  'feast',
#  'amongst',
#  'meat',
#  'pycelle',
#  'quick',
#  'understand',
#  'longer',
#  'lifted',
#  'whilst',
#  'reminded',
#  'maybe',
#  'mountain',
#  'short',
#  'had',
#  'step',
#  'rodrik',
#  'melisandre',
#  'ones',
#  'pretty',
#  'third',
#  'aegon',
#  'lands',
#  'bit',
#  'stopped',
#  'worse',
#  'sit',
#  'victarion',
#  'save',
#  'sharp',
#  'knows',
#  'whose',
#  'live',
#  'smoke',
#  'horn',
#  'leg',
#  'window',
#  'pray',
#  'younger',
#  'westeros',
#  'twenty',
#  'silk',
#  'heads',
#  'pie',
#  'septa',
#  'peace',
#  'slaves',
#  'ago',
#  'hizdahr',
#  'wants',
#  'bread',
#  'mind',
#  'low',
#  'laugh',
#  'east',
#  'blind',
#  'reek',
#  'towers',
#  'mad',
#  'bright',
#  'sooner',
#  'slain',
#  'coin',
#  'making',
#  'camp',
#  'older',
#  'own',
#  'salt',
#  'drowned',
#  'served',
#  'wait',
#  'narrow',
#  'walk',
#  'point',
#  'yours',
#  'glanced',
#  'cousin',
#  'cheeks',
#  'luwin',
#  'knife',
#  'stepped',
#  'shook',
#  'often',
#  'quiet',
#  'sort',
#  'targaryen',
#  'touched',
#  'riding',
#  'loras',
#  'naked',
#  'twisted',
#  'these',
#  'choice',
#  'kevan',
#  'fish',
#  'lion',
#  'forgotten',
#  'silence',
#  'ramsay',
#  'hung',
#  'read',
#  'gift',
#  'running',
#  'fallen',
#  'replied',
#  'large',
#  'knees',
#  'fought',
#  'silent',
#  'cat',
#  'company',
#  'ahead',
#  'beautiful',
#  'rhaegar',
#  'needs',
#  'dawn',
#  'sept',
#  'dogs',
#  'pass',
#  'dorne',
#  'casterly',
#  'knee',
#  'tully',
#  'mud',
#  'gregor',
#  'stupid',
#  'singer',
#  'court',
#  'body',
#  'meera',
#  'age',
#  'trying',
#  'top',
#  'swear',
#  'kind',
#  'does',
#  'gendry',
#  'offered',
#  'whole',
#  'clothes',
#  'leaves',
#  'closer',
#  'kiss',
#  'anything',
#  'whatever',
#  'wonder',
#  'pay',
#  'agreed',
#  'threw',
#  'answered',
#  'climbed',
#  'saying',
#  'wide',
#  'saddle',
#  'stars',
#  'comes',
#  'chain',
#  'trust',
#  'host',
#  'stones',
#  'pleased',
#  'trident',
#  'fair',
#  'yunkai',
#  'spears',
#  'hour',
#  'dry',
#  'dying',
#  'ear',
#  'insisted',
#  'most',
#  'eight',
#  'fast',
#  'carried',
#  'service',
#  'doors',
#  'ought',
#  'mail',
#  'fist',
#  'council',
#  'woods',
#  'thank',
#  'crossed',
#  'join',
#  'needed',
#  'milk',
#  'fine',
#  'wildling',
#  'quentyn',
#  'gilly',
#  'those',
#  'finger',
#  'tent',
#  'shadows',
#  'win',
#  'helped',
#  'land',
#  'bird',
#  'boots',
#  'folk',
#  'crows',
#  'imp',
#  'names',
#  'somehow',
#  'kissed',
#  'letter',
#  'banners',
#  'winter',
#  'pink',
#  'screamed',
#  'angry',
#  'frightened',
#  'torch',
#  'learn',
#  'alive',
#  'chair',
#  'eunuch',
#  'won',
#  'daughters',
#  'watching',
#  'tarly',
#  'harm',
#  'dragonstone',
#  'fires',
#  'serving',
#  'standing',
#  'easy',
#  'neither',
#  'nine',
#  'learned',
#  'wings',
#  'drunk',
#  'question',
#  'myrcella',
#  'priest',
#  'sail',
#  'sisters',
#  'nodded',
#  'harbor',
#  'bone',
#  'giant',
#  'forth',
#  'warned',
#  'field',
#  'slow',
#  'slipped',
#  'slid',
#  'dreams',
#  'bronze',
#  'slowly',
#  'falling',
#  'promise',
#  'atop',
#  'whore',
#  'slave',
#  'illyrio',
#  'line',
#  'move',
#  'rise',
#  'pyke',
#  'makes',
#  'flowers',
#  'laughter',
#  'grass',
#  'faced',
#  'declared',
#  'bay',
#  'earth',
#  'loose',
#  'power',
#  'viserys',
#  'lived',
#  'twice',
#  'front',
#  'cell',
#  'happened',
#  'play',
#  'chains',
#  'oldtown',
#  'break',
#  'an',
#  'dance',
#  'clean',
#  'aerys',
#  'surely',
#  'claim',
#  'unless',
#  'jeyne',
#  'eyrie',
#  'below',
#  'fresh',
#  'cried',
#  'tormund',
#  'craster',
#  'pair',
#  'laid',
#  'quite',
#  'shouting',
#  'morrow',
#  'were',
#  'sad',
#  'met',
#  'game',
#  'already',
#  'rule',
#  'touch',
#  'softly',
#  'steward',
#  'woke',
#  'count',
#  'started',
#  'mounted',
#  'afterward',
#  'sense',
#  'jojen',
#  'captive',
#  'highgarden',
#  'hide',
#  'waters',
#  'sudden',
#  'ravens',
#  'cheek',
#  'taking',
#  'however',
#  'anyone',
#  'course',
#  'follow',
#  'among',
#  'purple',
#  'means',
#  'wench',
#  'noble',
#  'carved',
#  'rickon',
#  'bare',
#  'grenn',
#  'waited',
#  'both',
#  'rising',
#  'murdered',
#  'vale',
#  'thinking',
#  'weak',
#  'cruel',
#  'roose',
#  'roof',
#  'hidden',
#  'eyed',
#  'arrow',
#  'town',
#  'blow',
#  'forest',
#  'wise',
#  'grand',
#  ...]

# %%
# Reduce dimensions of vectors to 3 for visulization
from sklearn.decomposition import PCA
pca = PCA(n_components=3)
X = pca.fit_transform(model.wv.get_normed_vectors())

# %%
# Plot the vectors of 100 words
import plotly.express as px
fig = px.scatter_3d(X[200:300], x=0, y=1, z=2, color=y[200:300])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1dcbf667-e613-4d5e-ad8e-19722d98d408" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1dcbf667-e613-4d5e-ad8e-19722d98d408")) {                    Plotly.newPlot(                        "1dcbf667-e613-4d5e-ad8e-19722d98d408",                        [{"hovertemplate":"color=nothing\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"nothing","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"nothing","scene":"scene","showlegend":true,"x":[0.21250138],"y":[0.42334306],"z":[-0.353856],"type":"scatter3d"},{"hovertemplate":"color=walls\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"walls","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"walls","scene":"scene","showlegend":true,"x":[-0.4547029],"y":[-0.51393336],"z":[-0.37231264],"type":"scatter3d"},{"hovertemplate":"color=fingers\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"fingers","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"fingers","scene":"scene","showlegend":true,"x":[-0.5998035],"y":[0.22986397],"z":[0.3370548],"type":"scatter3d"},{"hovertemplate":"color=house\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"house","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"house","scene":"scene","showlegend":true,"x":[0.193748],"y":[-0.7700684],"z":[0.44702306],"type":"scatter3d"},{"hovertemplate":"color=cloak\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"cloak","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"cloak","scene":"scene","showlegend":true,"x":[-0.51377904],"y":[-0.1939219],"z":[0.526587],"type":"scatter3d"},{"hovertemplate":"color=young\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"young","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers","name":"young","scene":"scene","showlegend":true,"x":[0.3521411],"y":[-0.48696935],"z":[0.4653431],"type":"scatter3d"},{"hovertemplate":"color=beside\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"beside","marker":{"color":"#FF6692","symbol":"circle"},"mode":"markers","name":"beside","scene":"scene","showlegend":true,"x":[-0.391693],"y":[-0.297041],"z":[0.35088897],"type":"scatter3d"},{"hovertemplate":"color=get\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"get","marker":{"color":"#B6E880","symbol":"circle"},"mode":"markers","name":"get","scene":"scene","showlegend":true,"x":[0.1369017],"y":[0.3387903],"z":[-0.2588115],"type":"scatter3d"},{"hovertemplate":"color=out\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"out","marker":{"color":"#FF97FF","symbol":"circle"},"mode":"markers","name":"out","scene":"scene","showlegend":true,"x":[-0.24062487],"y":[0.18912402],"z":[-0.07530923],"type":"scatter3d"},{"hovertemplate":"color=seven\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cbr\u003e2=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"seven","marker":{"color":"#FECB52","symbol":"circle"},"mode":"markers","name":"seven","scene":"scene","showlegend":true,"x":[0.24414083],"y":[-0.70189196],"z":[-0.13309088],"type":"scatter3d"},{"hovertemplate":"color=mouth\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{ ...
