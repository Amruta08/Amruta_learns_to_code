# %% [markdown]
# # Stemming

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
# Example 1
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

words = word_tokenize("eating eats eat ate adjustable rafting ability meeting better")

stemmer = PorterStemmer()
for word in words:
  print(word, ":", stemmer.stem(word))
# Out:
# eating : eat
# eats : eat
# eat : eat
# ate : ate
# adjustable : adjust
# rafting : raft
# ability : abil
# meeting : meet
# better : better

# %%
# Example 2
lst_words = ['running', 'painting', 'walking', 'dressing', 'likely', 'children', 'whom', 'good', 'ate', 'fishing']
for word in lst_words:
  print(word, ":", stemmer.stem(word))
# Out:
# running : run
# painting : paint
# walking : walk
# dressing : dress
# likely : like
# children : children
# whom : whom
# good : good
# ate : ate
# fishing : fish

# %%
# Example 3
text = """Latha is very multi talented girl.
She is good at many skills like dancing, running, singing, playing.
She also likes eating Pav Bhagi.
she has a habit of fishing and swimming too.
Besides all this, she is a wonderful at cooking too.
"""
stem_words = []

words = word_tokenize(text)
for word in words:
  stem_words.append(stemmer.stem(word))

" ".join(stem_words)
# Out:
# 'latha is veri multi talent girl . she is good at mani skill like danc , run , sing , play . she also like eat pav bhagi . she ha a habit of fish and swim too . besid all thi , she is a wonder at cook too .'

# %% [markdown]
# # Lemmatization

# %%
# Example 1
import spacy
nlp = spacy.load("en_core_web_sm")

doc = nlp("eating eats eat ate adjustable rafting ability meeting better")
for token in doc:
  print(token, ":", token.lemma_)
# Out:
# eating : eat
# eats : eat
# eat : eat
# ate : eat
# adjustable : adjustable
# rafting : raft
# ability : ability
# meeting : meet
# better : well

# %%
# Example 2
doc = nlp("running painting walking dressing likely children who good ate fishing")
for token in doc:
  print(token, ":", token.lemma_)
# Out:
# running : run
# painting : painting
# walking : walking
# dressing : dress
# likely : likely
# children : child
# who : who
# good : good
# ate : eat
# fishing : fish

# %%
# Example 3
text = """Latha is very multi talented girl.
She is good at many skills like dancing, running, singing, playing.
She also likes eating Pav Bhagi.
she has a habit of fishing and swimming too.
Besides all this, she is a wonderful at cooking too.
"""
lemma_words = []

doc = nlp(text)
for token in doc:
  lemma_words.append(token.lemma_)

" ".join(lemma_words)
# Out:
# 'Latha be very multi talented girl . \n she be good at many skill like dancing , running , singing , play . \n she also like eat Pav Bhagi . \n she have a habit of fishing and swim too . \n besides all this , she be a wonderful at cook too . \n'

# %% [markdown]
# # Customizing lemmatizer

# %%
doc = nlp("Bro, you wanna go? Brah, don't say no! I am exhausted")
for token in doc:
    print(token.text, "|", token.lemma_)
# Out:
# Bro | Bro
# , | ,
# you | you
# wanna | wanna
# go | go
# ? | ?
# Brah | Brah
# , | ,
# do | do
# n't | not
# say | say
# no | no
# ! | !
# I | I
# am | be
# exhausted | exhaust

# %%
nlp.pipe_names
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
# Adding custom rules
ar = nlp.get_pipe('attribute_ruler')
ar.add([[{"TEXT":"Bro"}], [{"TEXT":"Brah"}]],
       {"LEMMA":"Brother"})

# %%
doc = nlp("Bro, you wanna go? Brah, don't say no! I am exhausted")
for token in doc:
    print(token.text, "|", token.lemma_)
# Out:
# Bro | Brother
# , | ,
# you | you
# wanna | wanna
# go | go
# ? | ?
# Brah | Brother
# , | ,
# do | do
# n't | not
# say | say
# no | no
# ! | !
# I | I
# am | be
# exhausted | exhaust
