# %%
# !pip install ultralytics

# %% [markdown]
# # Object detection from image

# %%
# Load YOLO model and run on image
from ultralytics import YOLO
model = YOLO('yolov8n.pt')

results = model('fruits.jpg', show=True)
results[0].save('fruits_yolo.jpg')
# Out:
# image 1/1 /content/fruits.jpg: 448x640 1 banana, 3 apples, 193.4ms
# Speed: 4.5ms preprocess, 193.4ms inference, 1.6ms postprocess per image at shape (1, 3, 448, 640)
# 'fruits_yolo.jpg'

# %%
from PIL import Image
Image.open('fruits.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1150x767>

# %%
from PIL import Image
Image.open('fruits_yolo.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1150x767>

# %%
# View info about bounding boxes
for box in results[0].boxes:
  print(box)
# Out:
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([46.])
# conf: tensor([0.7548])
# data: tensor([[3.8182e+02, 3.1397e+02, 8.0119e+02, 5.0642e+02, 7.5484e-01, 4.6000e+01]])
# id: None
# is_track: False
# orig_shape: (767, 1150)
# shape: torch.Size([1, 6])
# xywh: tensor([[591.5044, 410.1933, 419.3752, 192.4452]])
# xywhn: tensor([[0.5144, 0.5348, 0.3647, 0.2509]])
# xyxy: tensor([[381.8168, 313.9707, 801.1920, 506.4159]])
# xyxyn: tensor([[0.3320, 0.4093, 0.6967, 0.6603]])
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([47.])
# conf: tensor([0.5976])
# data: tensor([[4.9435e+02, 1.5152e+02, 6.7275e+02, 3.2785e+02, 5.9757e-01, 4.7000e+01]])
# id: None
# is_track: False
# orig_shape: (767, 1150)
# shape: torch.Size([1, 6])
# xywh: tensor([[583.5464, 239.6813, 178.3973, 176.3304]])
# xywhn: tensor([[0.5074, 0.3125, 0.1551, 0.2299]])
# xyxy: tensor([[494.3477, 151.5161, 672.7451, 327.8465]])
# ...

# %%
for box in results[0].boxes:
    x1, y1, x2, y2 = box.xyxy[0]
    confidence = box.conf[0]
    class_id = int(box.cls[0])
    label = model.names[class_id]

    print(label, confidence.item())
# Out:
# banana 0.7548436522483826
# apple 0.5975683927536011
# apple 0.43215397000312805
# apple 0.3852996826171875

# %% [markdown]
# # Object detection in video

# %%
from ultralytics import YOLO
model = YOLO('yolov8n.pt')

model.predict('cars.mp4', save=True, conf=0.4)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Object detection in webcam

# %%
from ultralytics import YOLO
model = YOLO('yolov8n.pt')

model.predict(source=0, show=True, conf=0.5)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
