# %%
import pandas as pd
from IPython.display import display
from sklearn.model_selection import train_test_split


ion = pd.read_csv('ion.csv', index_col=0)
display(ion.head())

df = ion.copy()
df['Class'] = df['Class'].map({'good': 0, 'bad': 1})

# Split data into training and validation sets using train_test_split
X = df.drop('Class', axis=1)
y = df['Class']
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.3, random_state=0)


max_ = X_train.max(axis=0)
min_ = X_train.min(axis=0)

X_train = (X_train - min_) / (max_ - min_)
# Use the min/max from the training set to scale the validation set
X_valid = (X_valid - min_) / (max_ - min_)

# Drop columns with NaN values after scaling (only on features)
X_train.dropna(axis=1, inplace=True)
X_valid.dropna(axis=1, inplace=True)

# Align the columns of X_valid with X_train after dropping NaN columns
X_valid = X_valid[X_train.columns]
# Out:
#     V2       V3       V4       V5       V6       V7       V8       V9  \
# V1
# 1    0  0.99539 -0.05889  0.85243  0.02306  0.83398 -0.37708  1.00000
# 1    0  1.00000 -0.18829  0.93035 -0.36156 -0.10868 -0.93597  1.00000
# 1    0  1.00000 -0.03365  1.00000  0.00485  1.00000 -0.12062  0.88965
# 1    0  1.00000 -0.45161  1.00000  1.00000  0.71216 -1.00000  0.00000
# 1    0  1.00000 -0.02401  0.94140  0.06531  0.92106 -0.23255  0.77152
#
#         V10      V11  ...      V26      V27      V28      V29      V30  \
# V1                    ...
# 1   0.03760  0.85243  ... -0.51171  0.41078 -0.46168  0.21266 -0.34090
# 1  -0.04549  0.50874  ... -0.26569 -0.20468 -0.18401 -0.19040 -0.11593
# 1   0.01198  0.73082  ... -0.40220  0.58984 -0.22145  0.43100 -0.17365
# 1   0.00000  0.00000  ...  0.90695  0.51613  1.00000  1.00000 -0.20099
# 1  -0.16399  0.52798  ... -0.65158  0.13290 -0.53206  0.02431 -0.62197
#
#         V31      V32      V33      V34  Class
# V1
# ...

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    layers.Dense(4, activation='relu', input_shape=[32]),
    layers.Dense(4, activation='relu'),
    layers.Dense(1, activation='sigmoid'),
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['binary_accuracy'],
)

# %%
history_df = pd.DataFrame(history.history)
# Start the plot at epoch 5
history_df.loc[5:, ['loss', 'val_loss']].plot()
history_df.loc[5:, ['binary_accuracy', 'val_binary_accuracy']].plot()

print(("Best Validation Loss: {:0.4f}" +\
      "\nBest Validation Accuracy: {:0.4f}")\
      .format(history_df['val_loss'].min(),
              history_df['val_binary_accuracy'].max()))
