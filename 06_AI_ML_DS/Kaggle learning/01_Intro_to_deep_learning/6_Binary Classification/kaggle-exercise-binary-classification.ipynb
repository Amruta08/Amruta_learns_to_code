# %% [markdown]
# # Introduction #
#
# In this exercise, you'll build a model to predict hotel cancellations with a binary classifier.

# %%
# Setup plotting
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('animation', html='html5')

# Setup feedback system
from learntools.core import binder
binder.bind(globals())
from learntools.deep_learning_intro.ex6 import *
# Out:
# /tmp/ipykernel_33/3338970720.py:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %% [markdown]
# First, load the *Hotel Cancellations* dataset.

# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer

hotel = pd.read_csv('../input/dl-course-data/hotel.csv')

X = hotel.copy()
y = X.pop('is_canceled')

X['arrival_date_month'] = \
    X['arrival_date_month'].map(
        {'January':1, 'February': 2, 'March':3,
         'April':4, 'May':5, 'June':6, 'July':7,
         'August':8, 'September':9, 'October':10,
         'November':11, 'December':12}
    )

features_num = [
    "lead_time", "arrival_date_week_number",
    "arrival_date_day_of_month", "stays_in_weekend_nights",
    "stays_in_week_nights", "adults", "children", "babies",
    "is_repeated_guest", "previous_cancellations",
    "previous_bookings_not_canceled", "required_car_parking_spaces",
    "total_of_special_requests", "adr",
]
features_cat = [
    "hotel", "arrival_date_month", "meal",
    "market_segment", "distribution_channel",
    "reserved_room_type", "deposit_type", "customer_type",
]

transformer_num = make_pipeline(
    SimpleImputer(strategy="constant"), # there are a few missing values
    StandardScaler(),
)
transformer_cat = make_pipeline(
    SimpleImputer(strategy="constant", fill_value="NA"),
    OneHotEncoder(handle_unknown='ignore'),
)

preprocessor = make_column_transformer(
    (transformer_num, features_num),
    (transformer_cat, features_cat),
)

# stratify - make sure classes are evenlly represented across splits
X_train, X_valid, y_train, y_valid = \
    train_test_split(X, y, stratify=y, train_size=0.75)

X_train = preprocessor.fit_transform(X_train)
X_valid = preprocessor.transform(X_valid)

input_shape = [X_train.shape[1]]

# %% [markdown]
# # 1) Define Model #
#
# The model we'll use this time will have both batch normalization and dropout layers. To ease reading we've broken the diagram into blocks, but you can define it layer by layer as usual.
#
# Define a model with an architecture given by this diagram:
#
# <figure style="padding: 1em;">
# <img src="https://storage.googleapis.com/kaggle-media/learn/images/V04o59Z.png" width="400" alt="Diagram of network architecture: BatchNorm, Dense, BatchNorm, Dropout, Dense, BatchNorm, Dropout, Dense.">
# <figcaption style="textalign: center; font-style: italic"><center>Diagram of a binary classifier.</center></figcaption>
# </figure>

# %%
from tensorflow import keras
from tensorflow.keras import layers

# YOUR CODE HERE: define the model given in the diagram
model = keras.Sequential([
    layers.BatchNormalization(input_shape=input_shape),
    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(1, activation='sigmoid'),
])

# Check your answer
q_1.check()
# Out:
# Correct

# %% [markdown]
# # 2) Add Optimizer, Loss, and Metric #
#
# Now compile the model with the Adam optimizer and binary versions of the cross-entropy loss and accuracy metric.

# %%
# YOUR CODE HERE
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['binary_accuracy'],
)

# Check your answer
q_2.check()
# Out:
# Correct

# %%
# Lines below will give you a hint or solution code
#q_2.hint()
#q_2.solution()

# %% [markdown]
# Finally, run this cell to train the model and view the learning curves. It may run for around 60 to 70 epochs, which could take a minute or two.

# %%
early_stopping = keras.callbacks.EarlyStopping(
    patience=5,
    min_delta=0.001,
    restore_best_weights=True,
)
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=200,
    callbacks=[early_stopping],
)

history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot(title="Cross-entropy")
history_df.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot(title="Accuracy")
# Out:
# Epoch 1/200
# 175/175 [==============================] - 4s 15ms/step - loss: 0.4830 - binary_accuracy: 0.7725 - val_loss: 0.4322 - val_binary_accuracy: 0.7954
# Epoch 2/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.4216 - binary_accuracy: 0.8011 - val_loss: 0.4038 - val_binary_accuracy: 0.8088
# Epoch 3/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.4083 - binary_accuracy: 0.8083 - val_loss: 0.3983 - val_binary_accuracy: 0.8139
# Epoch 4/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.4018 - binary_accuracy: 0.8114 - val_loss: 0.3933 - val_binary_accuracy: 0.8172
# Epoch 5/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3965 - binary_accuracy: 0.8142 - val_loss: 0.3907 - val_binary_accuracy: 0.8194
# Epoch 6/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3923 - binary_accuracy: 0.8169 - val_loss: 0.3866 - val_binary_accuracy: 0.8215
# Epoch 7/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3883 - binary_accuracy: 0.8195 - val_loss: 0.3848 - val_binary_accuracy: 0.8241
# Epoch 8/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3850 - binary_accuracy: 0.8212 - val_loss: 0.3801 - val_binary_accuracy: 0.8256
# Epoch 9/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3822 - binary_accuracy: 0.8216 - val_loss: 0.3804 - val_binary_accuracy: 0.8258
# Epoch 10/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3788 - binary_accuracy: 0.8231 - val_loss: 0.3766 - val_binary_accuracy: 0.8285
# Epoch 11/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3762 - binary_accuracy: 0.8247 - val_loss: 0.3760 - val_binary_accuracy: 0.8259
# Epoch 12/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3732 - binary_accuracy: 0.8270 - val_loss: 0.3723 - val_binary_accuracy: 0.8275
# Epoch 13/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3710 - binary_accuracy: 0.8287 - val_loss: 0.3709 - val_binary_accuracy: 0.8297
# Epoch 14/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3695 - binary_accuracy: 0.8298 - val_loss: 0.3707 - val_binary_accuracy: 0.8295
# Epoch 15/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3678 - binary_accuracy: 0.8293 - val_loss: 0.3713 - val_binary_accuracy: 0.8290
# Epoch 16/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3657 - binary_accuracy: 0.8316 - val_loss: 0.3691 - val_binary_accuracy: 0.8302
# Epoch 17/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3648 - binary_accuracy: 0.8322 - val_loss: 0.3688 - val_binary_accuracy: 0.8292
# Epoch 18/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3625 - binary_accuracy: 0.8320 - val_loss: 0.3672 - val_binary_accuracy: 0.8308
# Epoch 19/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3608 - binary_accuracy: 0.8333 - val_loss: 0.3638 - val_binary_accuracy: 0.8334
# Epoch 20/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3607 - binary_accuracy: 0.8333 - val_loss: 0.3657 - val_binary_accuracy: 0.8316
# Epoch 21/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3586 - binary_accuracy: 0.8344 - val_loss: 0.3652 - val_binary_accuracy: 0.8323
# Epoch 22/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3569 - binary_accuracy: 0.8360 - val_loss: 0.3604 - val_binary_accuracy: 0.8348
# Epoch 23/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3566 - binary_accuracy: 0.8353 - val_loss: 0.3614 - val_binary_accuracy: 0.8355
# Epoch 24/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3542 - binary_accuracy: 0.8367 - val_loss: 0.3623 - val_binary_accuracy: 0.8347
# Epoch 25/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3530 - binary_accuracy: 0.8366 - val_loss: 0.3603 - val_binary_accuracy: 0.8344
# Epoch 26/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3511 - binary_accuracy: 0.8382 - val_loss: 0.3591 - val_binary_accuracy: 0.8356
# Epoch 27/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3509 - binary_accuracy: 0.8377 - val_loss: 0.3593 - val_binary_accuracy: 0.8374
# Epoch 28/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3504 - binary_accuracy: 0.8379 - val_loss: 0.3579 - val_binary_accuracy: 0.8359
# Epoch 29/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3483 - binary_accuracy: 0.8399 - val_loss: 0.3581 - val_binary_accuracy: 0.8340
# Epoch 30/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3460 - binary_accuracy: 0.8403 - val_loss: 0.3580 - val_binary_accuracy: 0.8344
# Epoch 31/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3452 - binary_accuracy: 0.8404 - val_loss: 0.3573 - val_binary_accuracy: 0.8355
# Epoch 32/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3456 - binary_accuracy: 0.8407 - val_loss: 0.3556 - val_binary_accuracy: 0.8355
# Epoch 33/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3431 - binary_accuracy: 0.8423 - val_loss: 0.3565 - val_binary_accuracy: 0.8354
# Epoch 34/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3438 - binary_accuracy: 0.8413 - val_loss: 0.3566 - val_binary_accuracy: 0.8358
# Epoch 35/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3425 - binary_accuracy: 0.8420 - val_loss: 0.3552 - val_binary_accuracy: 0.8386
# Epoch 36/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3420 - binary_accuracy: 0.8420 - val_loss: 0.3550 - val_binary_accuracy: 0.8365
# Epoch 37/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3392 - binary_accuracy: 0.8435 - val_loss: 0.3566 - val_binary_accuracy: 0.8350
# <Axes: title={'center': 'Accuracy'}>

# %% [markdown]
# # 3) Train and Evaluate #
#
#
# What do you think about the learning curves? Does it look like the model underfit or overfit? Was the cross-entropy loss a good stand-in for accuracy?

# %%
# View the solution (Run this cell to receive credit!)
q_3.check()
# Out:
# Correct:
#
# Though we can see the training loss continuing to fall, the early stopping callback prevented any overfitting. Moreover, the accuracy rose at the same rate as the cross-entropy fell, so it appears that minimizing cross-entropy was a good stand-in. All in all, it looks like this training was a success!
